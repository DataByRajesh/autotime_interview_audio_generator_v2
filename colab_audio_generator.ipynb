# %% [markdown]
# # Colab: Optional backup guide
#
# This notebook describes how you could run Piper or other local TTS runtimes on Google Colab as a temporary fallback.
#
# **Important:** This is optional — the project is local-first and does not require Colab.
